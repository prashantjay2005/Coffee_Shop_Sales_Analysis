# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../Datasets/CoffeeShopSales-cleaned.csv')

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# total_amount        0
# week                0
# weekday             0
# transaction_hour    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail',
#        'total_amount', 'week', 'weekday', 'transaction_hour'],
#       dtype='object')

# %%
df.dtypes
# Out:
# transaction_id        int64
# transaction_date     object
# transaction_time     object
# transaction_qty       int64
# store_id              int64
# store_location       object
# product_id            int64
# unit_price          float64
# product_category     object
# product_type         object
# product_detail       object
# total_amount        float64
# week                 object
# weekday              object
# transaction_hour      int64
# dtype: object

# %%
df['month'] = df['transaction_date'].astype('datetime64[ns]').dt.month_name()

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['transaction_time'] = df['transaction_time'].astype('datetime64[ns]')

# %%
df['transaction_date'] = df['transaction_time'].astype('datetime64[ns]')

# %%
df
# Out:
#         transaction_id    transaction_date    transaction_time  \
# 0                    1 2026-07-02 07:06:11 2026-07-02 07:06:11
# 1                    2 2026-07-02 07:08:56 2026-07-02 07:08:56
# 2                    3 2026-07-02 07:14:04 2026-07-02 07:14:04
# 3                    4 2026-07-02 07:20:24 2026-07-02 07:20:24
# 4                    5 2026-07-02 07:22:41 2026-07-02 07:22:41
# ...                ...                 ...                 ...
# 149111          149452 2026-07-02 20:18:41 2026-07-02 20:18:41
# 149112          149453 2026-07-02 20:25:10 2026-07-02 20:25:10
# 149113          149454 2026-07-02 20:31:34 2026-07-02 20:31:34
# 149114          149455 2026-07-02 20:57:19 2026-07-02 20:57:19
# 149115          149456 2026-07-02 20:57:19 2026-07-02 20:57:19
#
#         transaction_qty  store_id   store_location  product_id  unit_price  \
# 0                     2         5  Lower Manhattan          32        3.00
# ...

# %%
df.dtypes
# Out:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time    datetime64[ns]
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# total_amount               float64
# week                        object
# weekday                     object
# transaction_hour             int64
# month                       object
# dtype: object

# %%
print(df.store_location.unique)
# Out:
# <bound method Series.unique of 0         Lower Manhattan
# 1         Lower Manhattan
# 2         Lower Manhattan
# 3         Lower Manhattan
# 4         Lower Manhattan
#                ...
# 149111     Hell's Kitchen
# 149112     Hell's Kitchen
# 149113     Hell's Kitchen
# 149114     Hell's Kitchen
# 149115     Hell's Kitchen
# Name: store_location, Length: 149116, dtype: object>

# %%
print(df.product_category.unique)
# Out:
# <bound method Series.unique of 0                     Coffee
# 1                        Tea
# 2         Drinking Chocolate
# 3                     Coffee
# 4                        Tea
#                  ...
# 149111                   Tea
# 149112                   Tea
# 149113                   Tea
# 149114                Coffee
# 149115              Flavours
# Name: product_category, Length: 149116, dtype: object>

# %%
print(df.product_type.unique)
# Out:
# <bound method Series.unique of 0         Gourmet brewed coffee
# 1               Brewed Chai tea
# 2                 Hot chocolate
# 3                   Drip coffee
# 4               Brewed Chai tea
#                   ...
# 149111        Brewed herbal tea
# 149112         Brewed Black tea
# 149113        Brewed herbal tea
# 149114         Barista Espresso
# 149115            Regular syrup
# Name: product_type, Length: 149116, dtype: object>

# %%
print(df.product_detail.unique)
# Out:
# <bound method Series.unique of 0                         Ethiopia Rg
# 1            Spicy Eye Opener Chai Lg
# 2                   Dark chocolate Lg
# 3         Our Old Time Diner Blend Sm
# 4            Spicy Eye Opener Chai Lg
#                      ...
# 149111                  Peppermint Rg
# 149112           English Breakfast Lg
# 149113                  Peppermint Lg
# 149114                     Cappuccino
# 149115                 Hazelnut syrup
# Name: product_detail, Length: 149116, dtype: object>

# %%
print(df.week.unique)
# Out:
# <bound method Series.unique of 0         2022-12-26/2023-01-01
# 1         2022-12-26/2023-01-01
# 2         2022-12-26/2023-01-01
# 3         2022-12-26/2023-01-01
# 4         2022-12-26/2023-01-01
#                   ...
# 149111    2023-06-26/2023-07-02
# 149112    2023-06-26/2023-07-02
# 149113    2023-06-26/2023-07-02
# 149114    2023-06-26/2023-07-02
# 149115    2023-06-26/2023-07-02
# Name: week, Length: 149116, dtype: object>

# %%
print(df.weekday.unique)
# Out:
# <bound method Series.unique of 0         Sunday
# 1         Sunday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#            ...
# 149111    Friday
# 149112    Friday
# 149113    Friday
# 149114    Friday
# 149115    Friday
# Name: weekday, Length: 149116, dtype: object>

# %%
print(df.month.unique)
# Out:
# <bound method Series.unique of 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 149111       June
# 149112       June
# 149113       June
# 149114       June
# 149115       June
# Name: month, Length: 149116, dtype: object>

# %%
df['store_location'].value_counts()
# Out:
# store_location
# Hell's Kitchen     50735
# Astoria            50599
# Lower Manhattan    47782
# Name: count, dtype: int64

# %%
df['product_category'].value_counts()
# Out:
# product_category
# Coffee                58416
# Tea                   45449
# Bakery                22796
# Drinking Chocolate    11468
# Flavours               6790
# Coffee beans           1753
# Loose Tea              1210
# Branded                 747
# Packaged Chocolate      487
# Name: count, dtype: int64

# %%
df['product_type'].value_counts()
# Out:
# product_type
# Brewed Chai tea          17183
# Gourmet brewed coffee    16912
# Barista Espresso         16403
# Hot chocolate            11468
# Brewed Black tea         11350
# Brewed herbal tea        11245
# Scone                    10173
# Organic brewed coffee     8489
# Drip coffee               8477
# Premium brewed coffee     8135
# Pastry                    6912
# Biscotti                  5711
# Brewed Green tea          5671
# Regular syrup             4979
# Sugar free syrup          1811
# Housewares                 526
# Chai tea                   443
# Organic Beans              415
# Gourmet Beans              366
# Premium Beans              336
# Espresso Beans             319
# Herbal tea                 305
# Black tea                  303
# Drinking Chocolate         266
# Organic Chocolate          221
# Clothing                   221
# House blend Beans          183
# Green tea                  159
# Green beans                134
# Name: count, dtype: int64

# %%
df['product_detail'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                         Ethiopia Rg
# 1            Spicy Eye Opener Chai Lg
# 2                   Dark chocolate Lg
# 3         Our Old Time Diner Blend Sm
# 4            Spicy Eye Opener Chai Lg
#                      ...
# 149111                  Peppermint Rg
# 149112           English Breakfast Lg
# 149113                  Peppermint Lg
# 149114                     Cappuccino
# 149115                 Hazelnut syrup
# Name: product_detail, Length: 149116, dtype: object>

# %%
df['total_amount'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         6.00
# 1         6.20
# 2         9.00
# 3         2.00
# 4         6.20
#           ...
# 149111    5.00
# 149112    6.00
# 149113    3.00
# 149114    3.75
# 149115    1.60
# Name: total_amount, Length: 149116, dtype: float64>

# %%
df['week'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         2022-12-26/2023-01-01
# 1         2022-12-26/2023-01-01
# 2         2022-12-26/2023-01-01
# 3         2022-12-26/2023-01-01
# 4         2022-12-26/2023-01-01
#                   ...
# 149111    2023-06-26/2023-07-02
# 149112    2023-06-26/2023-07-02
# 149113    2023-06-26/2023-07-02
# 149114    2023-06-26/2023-07-02
# 149115    2023-06-26/2023-07-02
# Name: week, Length: 149116, dtype: object>

# %%
df['weekday'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Sunday
# 1         Sunday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#            ...
# 149111    Friday
# 149112    Friday
# 149113    Friday
# 149114    Friday
# 149115    Friday
# Name: weekday, Length: 149116, dtype: object>

# %%
df['month'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 149111       June
# 149112       June
# 149113       June
# 149114       June
# 149115       June
# Name: month, Length: 149116, dtype: object>

# %%
df.describe()
# Out:
#        transaction_id               transaction_date  \
# count   149116.000000                         149116
# mean     74737.371872  2026-07-02 12:14:15.815794432
# min          1.000000            2026-07-02 06:00:00
# 25%      37335.750000     2026-07-02 09:05:10.500000
# 50%      74727.500000            2026-07-02 11:15:28
# 75%     112094.250000            2026-07-02 15:25:57
# max     149456.000000            2026-07-02 20:59:32
# std      43153.600016                            NaN
#
#                     transaction_time  transaction_qty       store_id  \
# count                         149116    149116.000000  149116.000000
# mean   2026-07-02 12:14:15.815794432         1.438276       5.342063
# min              2026-07-02 06:00:00         1.000000       3.000000
# 25%       2026-07-02 09:05:10.500000         1.000000       3.000000
# 50%              2026-07-02 11:15:28         1.000000       5.000000
# 75%              2026-07-02 15:25:57         2.000000       8.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   transaction_id  transaction_qty  store_id  product_id  \
# transaction_id          1.000000         0.010250 -0.006054    0.001076
# transaction_qty         0.010250         1.000000 -0.000794   -0.175255
# store_id               -0.006054        -0.000794  1.000000    0.025727
# product_id              0.001076        -0.175255  0.025727    1.000000
# unit_price              0.000836        -0.123546  0.001891   -0.140423
# total_amount            0.005949         0.356231  0.004595   -0.167461
# transaction_hour       -0.012488        -0.006310 -0.075813   -0.031644
#
#                   unit_price  total_amount  transaction_hour
# transaction_id      0.000836      0.005949         -0.012488
# transaction_qty    -0.123546      0.356231         -0.006310
# store_id            0.001891      0.004595         -0.075813
# product_id         -0.140423     -0.167461         -0.031644
# unit_price          1.000000      0.685550         -0.018435
# ...

# %%
a=df.groupby('store_location')['total_amount'].sum().reset_index(name='sales')
a
# Out:
#     store_location      sales
# 0          Astoria  232243.91
# 1   Hell's Kitchen  236511.17
# 2  Lower Manhattan  230057.25

# %%
df.groupby('month')['total_amount'].sum()
# Out:
# month
# April       118941.08
# February     76145.19
# January      81677.74
# June        166485.88
# March        98834.68
# May         156727.76
# Name: total_amount, dtype: float64

# %%
b=df.groupby('product_category')['total_amount'].sum().reset_index(name='sales')
b
# Out:
#      product_category      sales
# 0              Bakery   82315.64
# 1             Branded   13607.00
# 2              Coffee  269952.45
# 3        Coffee beans   40085.25
# 4  Drinking Chocolate   72416.00
# 5            Flavours    8408.80
# 6           Loose Tea   11213.60
# 7  Packaged Chocolate    4407.64
# 8                 Tea  196405.95

# %%
df.groupby('product_category')['total_amount'].sum().nlargest(5)
# Out:
# product_category
# Coffee                269952.45
# Tea                   196405.95
# Bakery                 82315.64
# Drinking Chocolate     72416.00
# Coffee beans           40085.25
# Name: total_amount, dtype: float64

# %%
df.groupby('product_category')['total_amount'].nlargest(5)
# Out:
# product_category
# Bakery              3890        9.00
#                     4097        9.00
#                     4275        9.00
#                     21625       9.00
#                     21636       9.00
# Branded             39176      72.00
#                     61622      72.00
#                     123186     72.00
#                     16490      56.00
#                     123153     56.00
# Coffee              94332      17.00
#                     129128     17.00
#                     9366       12.75
#                     9851       12.75
#                     9874       12.75
# Coffee beans        9310      360.00
#                     9365      360.00
#                     68806     360.00
#                     68981     360.00
#                     97979     360.00
# Drinking Chocolate  13114      14.25
#                     13700      14.25
#                     14480      14.25
#                     15339      14.25
#                     29128      14.25
# ...

# %%
df.groupby('product_type')['transaction_qty'].nlargest(10)
# Out:
# product_type
# Barista Espresso  94332     4
#                   129128    4
#                   7831      3
#                   9366      3
#                   9851      3
#                            ..
# Sugar free syrup  60777     4
#                   87987     4
#                   122099    4
#                   4088      3
#                   5976      3
# Name: transaction_qty, Length: 290, dtype: int64

# %%
df.groupby('product_type')['transaction_qty'].nsmallest(10)
# Out:
# product_type
# Barista Espresso  8       1
#                   24      1
#                   30      1
#                   55      1
#                   62      1
#                          ..
# Sugar free syrup  3831    1
#                   4152    1
#                   4160    1
#                   4222    1
#                   4656    1
# Name: transaction_qty, Length: 290, dtype: int64

# %%
df.groupby('weekday')['total_amount'].mean()
# Out:
# weekday
# Friday       4.671352
# Monday       4.697929
# Saturday     4.724255
# Sunday       4.661088
# Thursday     4.653541
# Tuesday      4.690875
# Wednesday    4.707346
# Name: total_amount, dtype: float64

# %%
pd.pivot_table(df,index='product_category',columns='store_location',values='total_amount',margins=True)
# Out:
# store_location        Astoria  Hell's Kitchen  Lower Manhattan        All
# product_category
# Bakery               3.649300        3.595503         3.590487   3.610969
# Branded             19.559140       16.319328        17.787966  18.215529
# Coffee               4.481613        4.518881         4.888239   4.621207
# Coffee beans        20.356972       25.882083        21.150565  22.866657
# Drinking Chocolate   6.124477        6.267938         6.606314   6.314615
# Flavours             1.184430        1.213840         1.285734   1.238409
# Loose Tea            9.284884        9.198660         9.339239   9.267438
# Packaged Chocolate   9.906455        8.623198         8.995333   9.050595
# Tea                  4.172196        4.235210         4.590623   4.321458
# All                  4.589891        4.661696         4.814726   4.686367

# %%
pd.pivot_table(df,index='weekday',columns='store_location',values='total_amount',margins=True)
# Out:
# store_location   Astoria  Hell's Kitchen  Lower Manhattan       All
# weekday
# Friday          4.552877        4.639228         4.833392  4.671352
# Monday          4.583046        4.700100         4.814950  4.697929
# Saturday        4.587429        4.761792         4.827331  4.724255
# Sunday          4.636672        4.586823         4.768603  4.661088
# Thursday        4.596791        4.580274         4.791814  4.653541
# Tuesday         4.524568        4.663607         4.895896  4.690875
# Wednesday       4.646490        4.709200         4.771660  4.707346
# All             4.589891        4.661696         4.814726  4.686367

# %%
pd.pivot_table(df,index='product_type',columns='product_category',values='transaction_qty',margins=True)
# Out:
# product_category         Bakery   Branded    Coffee  Coffee beans  \
# product_type
# Barista Espresso            NaN       NaN  1.520636           NaN
# Biscotti               1.013483       NaN       NaN           NaN
# Black tea                   NaN       NaN       NaN           NaN
# Brewed Black tea            NaN       NaN       NaN           NaN
# Brewed Chai tea             NaN       NaN       NaN           NaN
# Brewed Green tea            NaN       NaN       NaN           NaN
# Brewed herbal tea           NaN       NaN       NaN           NaN
# Chai tea                    NaN       NaN       NaN           NaN
# Clothing                    NaN  1.000000       NaN           NaN
# Drinking Chocolate          NaN       NaN       NaN           NaN
# Drip coffee                 NaN       NaN  1.520703           NaN
# Espresso Beans              NaN       NaN       NaN      1.000000
# Gourmet Beans               NaN       NaN       NaN      1.000000
# ...

# %%
pd.pivot_table(df,index='month',columns='product_category',values='transaction_qty',margins=True)
# Out:
# product_category    Bakery   Branded    Coffee  Coffee beans  \
# month
# April             1.020666  1.044118  1.531722      1.050847
# February          1.016283  1.013699  1.526067      1.000000
# January           1.017783  1.041667  1.524812      1.068493
# June              1.018376  1.059783  1.531605      1.074813
# March             1.020669  1.061224  1.521855      1.000000
# May               1.016339  1.006250  1.527061      1.038265
# All               1.018337  1.038822  1.527835      1.042784
#
# product_category  Drinking Chocolate  Flavours  Loose Tea  Packaged Chocolate  \
# month
# April                       1.517738  1.548472        1.0                 1.0
# February                    1.516602  1.556894        1.0                 1.0
# January                     1.511628  1.569588        1.0                 1.0
# June                        1.529696  1.540823        1.0                 1.0
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
print(df.store_location.unique())
s=input("enter store location name")
ss=df[df.store_location==s]

print(ss.product_category.unique())
p=input("enter category name")
pp=ss[ss.product_category==p]

q=pp.groupby('product_type')['total_amount'].mean()
sb.barplot(q)
plt.show()
# Out:
# ['Lower Manhattan' "Hell's Kitchen" 'Astoria']
# enter store location name Astoria
# ['Coffee' 'Bakery' 'Drinking Chocolate' 'Tea' 'Loose Tea' 'Coffee beans'
#  'Branded' 'Packaged Chocolate' 'Flavours']
# enter category name Packaged Chocolate

# %%
sb.countplot(x=df.store_location)
# Out:
# <Axes: xlabel='store_location', ylabel='count'>

# %%
sb.countplot(x=df.product_category)
plt.xticks(rotation=90)
plt.show()

# %%
sb.countplot(x=df.product_type)
plt.xticks(rotation=90)
plt.show()

# %%
sb.countplot(x=df.weekday)
# Out:
# <Axes: xlabel='weekday', ylabel='count'>

# %%
sb.barplot(x=a.store_location, y=a.sales)
# Out:
# <Axes: xlabel='store_location', ylabel='sales'>

# %%
sb.barplot(x=b.product_category, y=b.sales)
plt.xticks(rotation=90)
plt.show()

# %%
r = df.groupby('product_category')['transaction_qty'].mean()
sb.barplot(r)
plt.xticks(rotation=90)
plt.show()

# %%
sb.lineplot(x=df.weekday,y=df.total_amount)
plt.title("total amount vs weekday")
plt.show()

# %%
m=df.groupby('month')['total_amount'].mean()
sb.lineplot(m)
plt.show()

# %%
a=df.groupby('product_category')['total_amount'].mean()
plt.pie(a.values,labels=a.index,
autopct='%d%%')
plt.title("sales distrubution by product category")
plt.show()

# %%
b=df.groupby('store_location')['total_amount'].mean()
plt.figure(figsize=(8,8))
plt.pie(b.values,labels=b.index,autopct='%d%%')
plt.show()

# %%
sb.histplot(df.total_amount,bins=5)
plt.show()

# %%
sb.histplot(df.transaction_qty,bins=5)
plt.show()

# %%
sb.histplot(df.unit_price,bins=5)
plt.show()

# %%
sb.pointplot(x=df.total_amount, y=df.product_category)
plt.show()

# %%
sb.pointplot(x=df.store_location,y=df.total_amount)
plt.show()

# %%
sb.stripplot(x=df.total_amount, y=df.product_category)
plt.show()

# %%
sb.violinplot(df.total_amount)
plt.show()

# %%
sb.violinplot(df.unit_price)
plt.show()

# %%
sb.swarmplot(df.transaction_qty)
plt.show()

# %%
sb.swarmplot(df.unit_price)

# %%
sb.scatterplot(x=df.unit_price,y=df.transaction_qty)
# Out:
# <Axes: xlabel='unit_price', ylabel='transaction_qty'>

# %%
df
# Out:
#         transaction_id    transaction_date    transaction_time  \
# 0                    1 2026-07-02 07:06:11 2026-07-02 07:06:11
# 1                    2 2026-07-02 07:08:56 2026-07-02 07:08:56
# 2                    3 2026-07-02 07:14:04 2026-07-02 07:14:04
# 3                    4 2026-07-02 07:20:24 2026-07-02 07:20:24
# 4                    5 2026-07-02 07:22:41 2026-07-02 07:22:41
# ...                ...                 ...                 ...
# 149111          149452 2026-07-02 20:18:41 2026-07-02 20:18:41
# 149112          149453 2026-07-02 20:25:10 2026-07-02 20:25:10
# 149113          149454 2026-07-02 20:31:34 2026-07-02 20:31:34
# 149114          149455 2026-07-02 20:57:19 2026-07-02 20:57:19
# 149115          149456 2026-07-02 20:57:19 2026-07-02 20:57:19
#
#         transaction_qty  store_id   store_location  product_id  unit_price  \
# 0                     2         5  Lower Manhattan          32        3.00
# ...

# %%
sb.pairplot(df[['unit_price', 'total_amount', 'transaction_qty']])

# %%
sb.jointplot(x=df.unit_price,y=df.total_amount)

# %%
sb.jointplot(x=df.transaction_qty,y=df.total_amount)

# %%
sb.kdeplot(df.total_amount)
# Out:
# <Axes: xlabel='total_amount', ylabel='Density'>

# %%
sb.kdeplot(df.transaction_qty)
# Out:
# <Axes: xlabel='transaction_qty', ylabel='Density'>
